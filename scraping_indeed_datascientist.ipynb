# %%
from bs4 import BeautifulSoup # For HTML parsing
import urllib2 # Website connections
import re # Regular expressions
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd # For converting results to a dataframe and bar chart plots
# %matplotlib inline

# %%
def text_cleaner(website):
    '''
    This function just cleans up the raw html so that I can look at it.
    Inputs: a URL to investigate
    Outputs: Cleaned text only
    '''
    try:
        site = urllib2.urlopen(website).read() # Connect to the job posting
    except: 
        return   # Need this in case the website isn't there anymore or some other weird connection problem 
    
    soup_obj = BeautifulSoup(site, "lxml") # Get the html from the site
    
    for script in soup_obj(["script", "style"]):
        script.extract() # Remove these two elements from the BS4 object
    
    

    text = soup_obj.get_text() # Get the text from this
    
        
    
    lines = (line.strip() for line in text.splitlines()) # break into lines
    
        
        
    chunks = (phrase.strip() for line in lines for phrase in line.split("  ")) # break multi-headlines into a line each
    
    def chunk_space(chunk):
        chunk_out = chunk + ' ' # Need to fix spacing issue
        return chunk_out  
        
    
    text = ''.join(chunk_space(chunk) for chunk in chunks if chunk).encode('utf-8') # Get rid of all blank lines and ends of line
        
        
    # Now clean out all of the unicode junk (this line works great!!!)
        
    try:
        text = text.decode('unicode_escape').encode('ascii', 'ignore') # Need this as some websites aren't formatted
    except:                                                            # in a way that this works, can occasionally throw
        return                                                         # an exception
       
        
    text = re.sub("[^a-zA-Z.+3]"," ", text)  # Now get rid of any terms that aren't words (include 3 for d3.js)
                                                # Also include + for C++
        
       
    text = text.lower().split()  # Go to lower case and split them apart
        
        
    stop_words = set(stopwords.words("english")) # Filter out any stop words
    text = [w for w in text if not w in stop_words]
        
        
        
    text = list(set(text)) # Last, just get the set of these. Ignore counts (we are just looking at whether a term existed
                            # or not on the website)
        
    return text

# %%
def skills_info(city = None, state = None):
    '''
    This function will take a desired city/state and look for all new job postings
    on Indeed.ca. It will crawl all of the job postings and keep track of how many
    use a preset list of typical data science skills. The final percentage for each skill
    is then displayed at the end of the collation. 
    
    Inputs: The location's city and state. These are optional. If no city/state is input, 
    the function will assume a national search (this can take a while!!!).
    Input the city/state as strings, such as skills_info('Chicago', 'IL').
    Use a two letter abbreviation for the state.
    
    Output: A bar chart showing the most commonly desired skills in the job market for 
    a data scientist. 
    '''
    
    final_job = 'data+scientist' # searching for data scientist exact fit("data scientist" on Indeed search)
    
    
    # Make sure the city specified works properly if it has more than one word (such as San Francisco)
    if city is not None:
        final_city = city.split() 
        final_city = '+'.join(word for word in final_city)
        final_site_list = ['http://www.indeed.com/jobs?q=%22', final_job, '%22&l=', final_city,
                   '%2C+', state] # Join all of our strings together so that indeed will search correctly
    else:
        final_site_list = ['http://www.indeed.com/jobs?q="', final_job, '"']

    final_site = ''.join(final_site_list) # Merge the html address together into one string


    base_url = 'http://www.indeed.com'


    try:
        html = urllib2.urlopen(final_site).read() # Open up the front page of our search first
    except:
        'That city/state combination did not have any jobs. Exiting . . .' # In case the city is invalid
        return
    soup = BeautifulSoup(html, "lxml") # Get the html from the first page

    # Now find out how many jobs there were

    num_jobs_area = soup.find(id = 'searchCount').string.encode('utf-8') # Now extract the total number of jobs found
                                                                         # The 'searchCount' object has this

    job_numbers = re.findall('\d+', num_jobs_area) # Extract the total jobs found from the search result


    if len(job_numbers) > 3: # Have a total number of jobs greater than 1000
        total_num_jobs = (int(job_numbers[2])*1000) + int(job_numbers[3])
    else:
        total_num_jobs = int(job_numbers[2]) 

    city_title = city
    if city is None:
        city_title = 'Nationwide'
    
    print 'There were', total_num_jobs, 'jobs found,', city_title # Display how many jobs were found

    num_pages = total_num_jobs/10 # This will be how we know the number of times we need to iterate over each new
                                  # search result page
    job_descriptions = [] # Store all our descriptions in this list

    for i in xrange(1,num_pages+1): # Loop through all of our search result pages
        print 'Getting page', i
        start_num = str(i*10) # Assign the multiplier of 10 to view the pages we want
        current_page = ''.join([final_site, '&start=', start_num])
        # Now that we can view the correct 10 job returns, start collecting the text samples from each
        
        html_page = urllib2.urlopen(current_page).read() # Get the page
        
        page_obj = BeautifulSoup(html_page, "lxml") # Locate all of the job links
        job_link_area = page_obj.find(id = 'resultsCol') # The center column on the page where the job postings exist
        
        job_URLS = [base_url + link.get('href') for link in job_link_area.find_all('a')] # Get the URLS for the jobs
        
        job_URLS = filter(lambda x:'clk' in x, job_URLS) # Now get just the job related URLS
        
    
        for j in xrange(0,len(job_URLS)):
            final_description = text_cleaner(job_URLS[j])
            if final_description: # So that we only append when the website was accessed correctly
                job_descriptions.append(final_description)
            sleep(1) # So that we don't be jerks. If you have a very fast internet connection you could hit the server a lot! 
    
    print 'Done with collecting the job postings!'    
    print 'There were', len(job_descriptions), 'jobs successfully found.'


    doc_frequency = Counter() # This will create a full counter of our terms. 
    [doc_frequency.update(item) for item in job_descriptions] # List comp

    # Now we can just look at our final dict list inside doc_frequency

    # Obtain our key terms and store them in a dict. These are the key data science skills we are looking for

    prog_lang_dict = Counter({'R':doc_frequency['r'], 'Python':doc_frequency['python'],
                    'Java':doc_frequency['java'], 'C++':doc_frequency['c++'],
                   'Ruby':doc_frequency['ruby'],
                  'Perl':doc_frequency['perl'], 'Matlab':doc_frequency['matlab'],
                  'JavaScript':doc_frequency['javascript'], 'Scala': doc_frequency['scala']})
                  
    analysis_tool_dict = Counter({'Excel':doc_frequency['excel'],  'Tableau':doc_frequency['tableau'],
                      'D3.js':doc_frequency['d3.js'], 'SAS':doc_frequency['sas'],
                      'SPSS':doc_frequency['spss'], 'D3':doc_frequency['d3']})  

    hadoop_dict = Counter({'Hadoop':doc_frequency['hadoop'], 'MapReduce':doc_frequency['mapreduce'],
               'Spark':doc_frequency['spark'], 'Pig':doc_frequency['pig'],
               'Hive':doc_frequency['hive'], 'Shark':doc_frequency['shark'],
               'Oozie':doc_frequency['oozie'], 'ZooKeeper':doc_frequency['zookeeper'],
               'Flume':doc_frequency['flume'], 'Mahout':doc_frequency['mahout']})
               
    database_dict = Counter({'SQL':doc_frequency['sql'], 'NoSQL':doc_frequency['nosql'],
                 'HBase':doc_frequency['hbase'], 'Cassandra':doc_frequency['cassandra'],
                 'MongoDB':doc_frequency['mongodb']})
                 
           
    overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects

    

    final_frame = pd.DataFrame(overall_total_skills.items(), columns = ['Term', 'NumPostings']) # Convert these terms to a 
                                                                                                # dataframe 

    # Change the values to reflect a percentage of the postings 

    final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings 
                                                                                  #  having that term 

    # Sort the data for plotting purposes

    final_frame.sort(columns = 'NumPostings', ascending = False, inplace = True)

    # Get it ready for a bar plot
    
    final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None, 
                              title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + city_title)
    
    final_plot.set_ylabel('Percentage Appearing in Job Ads')
    fig = final_plot.get_figure() # Have to convert the pandas plot object to a matplotlib object
    
    
    return fig, final_frame # End of the function

# %%
figure, frame = skills_info(city = 'Seattle', state = 'WA')
frame.to_csv('SeattleSkills.csv', index = False)
# Out:
# There were 223 jobs found, Seattle
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Getting page 13
# Getting page 14
# Getting page 15
# Getting page 16
# Getting page 17
# Getting page 18
# Getting page 19
# Getting page 20
# Getting page 21
# Getting page 22
# Done with collecting the job postings!
# There were 141 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'New York', state = 'NY')
frame.to_csv('NewYorkSkills.csv', index = False)
# Out:
# There were 344 jobs found, New York
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Getting page 13
# Getting page 14
# Getting page 15
# Getting page 16
# Getting page 17
# Getting page 18
# Getting page 19
# Getting page 20
# Getting page 21
# Getting page 22
# Getting page 23
# Getting page 24
# Getting page 25
# Getting page 26
# Getting page 27
# Getting page 28
# Getting page 29
# Getting page 30
# Getting page 31
# Getting page 32
# Getting page 33
# Getting page 34
# Done with collecting the job postings!
# There were 251 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Los Angeles', state = 'CA')
frame.to_csv('LosAngelesSkills.csv', index = False)
# Out:
# There were 93 jobs found, Los Angeles
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Done with collecting the job postings!
# There were 46 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Chicago', state = 'IL')
frame.to_csv('ChicagoSkills.csv', index = False)
# Out:
# There were 125 jobs found, Chicago
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Done with collecting the job postings!
# There were 78 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Houston', state = 'TX')
frame.to_csv('HoustonSkills.csv', index = False)
# Out:
# There were 19 jobs found, Houston
# Getting page 1
# Done with collecting the job postings!
# There were 4 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Philadelphia', state = 'PA')
frame.to_csv('PhiladelphiaSkills.csv', index = False)
# Out:
# There were 60 jobs found, Philadelphia
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Done with collecting the job postings!
# There were 31 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Phoenix', state = 'AZ')
frame.to_csv('PhoenixSkills.csv', index = False)
# Out:
# There were 18 jobs found, Phoenix
# Getting page 1
# Done with collecting the job postings!
# There were 5 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'San Antonio', state = 'TX')
frame.to_csv('SanAntonioSkills.csv', index = False)
# Out:
# There were 4 jobs found, San Antonio
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-870aceafe11a> in <module>()
# ----> 1 figure, frame = skills_info(city = 'San Antonio', state = 'TX')
#       2 frame.to_csv('SanAntonioSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'San Diego', state = 'CA')
frame.to_csv('SanDiegoSkills.csv', index = False)
# Out:
# There were 39 jobs found, San Diego
# Getting page 1
# Getting page 2
# Getting page 3
# Done with collecting the job postings!
# There were 17 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Dallas', state = 'TX')
frame.to_csv('DallasSkills.csv', index = False)
# Out:
# There were 55 jobs found, Dallas
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Done with collecting the job postings!
# There were 27 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'San Jose', state = 'CA')
frame.to_csv('SanJoseSkills.csv', index = False)
# Out:
# There were 288 jobs found, San Jose
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Getting page 13
# Getting page 14
# Getting page 15
# Getting page 16
# Getting page 17
# Getting page 18
# Getting page 19
# Getting page 20
# Getting page 21
# Getting page 22
# Getting page 23
# Getting page 24
# Getting page 25
# Getting page 26
# Getting page 27
# Getting page 28
# Done with collecting the job postings!
# There were 193 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Austin', state = 'TX')
frame.to_csv('AustinSkills.csv', index = False)
# Out:
# There were 37 jobs found, Austin
# Getting page 1
# Getting page 2
# Getting page 3
# Done with collecting the job postings!
# There were 16 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Jacksonville', state = 'FL')
frame.to_csv('JacksonvilleSkills.csv', index = False)
# Out:
# There were 3 jobs found, Jacksonville
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-d1627d176ebf> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Jacksonville', state = 'FL')
#       2 frame.to_csv('JacksonvilleSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Indianapolis', state = 'IN')
frame.to_csv('IndianapolisSkills.csv', index = False)
# Out:
# There were 16 jobs found, Indianapolis
# Getting page 1
# Done with collecting the job postings!
# There were 3 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'San Francisco', state = 'CA')
frame.to_csv('SanFranciscoSkills.csv', index = False)
# Out:
# There were 366 jobs found, San Francisco
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Getting page 13
# Getting page 14
# Getting page 15
# Getting page 16
# Getting page 17
# Getting page 18
# Getting page 19
# Getting page 20
# Getting page 21
# Getting page 22
# Getting page 23
# Getting page 24
# Getting page 25
# Getting page 26
# Getting page 27
# Getting page 28
# Getting page 29
# Getting page 30
# Getting page 31
# Getting page 32
# Getting page 33
# Getting page 34
# Getting page 35
# Getting page 36
# Done with collecting the job postings!
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# There were 253 jobs successfully found.

# %%
figure, frame = skills_info(city = 'Columbus', state = 'OH')
frame.to_csv('ColumbusSkills.csv', index = False)
# Out:
# There were 15 jobs found, Columbus
# Getting page 1
# Done with collecting the job postings!
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# There were 3 jobs successfully found.

# %%
figure, frame = skills_info(city = 'Fort Worth', state = 'TX')
frame.to_csv('FortWorthSkills.csv', index = False)
# Out:
# There were 29 jobs found, Fort Worth
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 6 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Charlotte', state = 'NC')
frame.to_csv('CharlotteSkills.csv', index = False)
# Out:
# There were 10 jobs found, Charlotte
# Getting page 1
# Done with collecting the job postings!
# There were 10 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Detroit', state = 'MI')
frame.to_csv('DetroitSkills.csv', index = False)
# Out:
# There were 43 jobs found, Detroit
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Done with collecting the job postings!
# There were 15 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'El Paso', state = 'TX')
frame.to_csv('ElPasoSkills.csv', index = False)
# Out:
# There were 4 jobs found, El Paso
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-a277ab236e05> in <module>()
# ----> 1 figure, frame = skills_info(city = 'El Paso', state = 'TX')
#       2 frame.to_csv('ElPasoSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
#figure, frame = skills_info(city = 'Memphis', state = 'TN')
#frame.to_csv('MemphisSkills.csv', index = False)
# Out:
# There were 21 jobs found, Memphis
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 14 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Boston', state = 'MA')
frame.to_csv('BostonSkills.csv', index = False)
# Out:
# There were 177 jobs found, Boston
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Getting page 13
# Getting page 14
# Getting page 15
# Getting page 16
# Getting page 17
# Done with collecting the job postings!
# There were 119 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Denver', state = 'CO')
frame.to_csv('DenverSkills.csv', index = False)
# Out:
# There were 51 jobs found, Denver
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Done with collecting the job postings!
# There were 31 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Washington', state = 'DC')
frame.to_csv('WashingtonSkills.csv', index = False)
# Out:
# There were 277 jobs found, Washington
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Getting page 13
# Getting page 14
# Getting page 15
# Getting page 16
# Getting page 17
# Getting page 18
# Getting page 19
# Getting page 20
# Getting page 21
# Getting page 22
# Getting page 23
# Getting page 24
# Getting page 25
# Getting page 26
# Getting page 27
# Done with collecting the job postings!
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# There were 189 jobs successfully found.

# %%
figure, frame = skills_info(city = 'Nashville', state = 'TN')
frame.to_csv('NashvilleSkills.csv', index = False)
# Out:
# There were 13 jobs found, Nashville
# Getting page 1
# Done with collecting the job postings!
# There were 1 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Baltimore', state = 'MD')
frame.to_csv('BaltimoreSkills.csv', index = False)
# Out:
# There were 46 jobs found, Baltimore
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Done with collecting the job postings!
# There were 31 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Louisville', state = 'KY')
frame.to_csv('LouisvilleSkills.csv', index = False)
# Out:
# There were 4 jobs found, Louisville
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-134fd01a61bd> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Louisville', state = 'KY')
#       2 frame.to_csv('LouisvilleSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Portland', state = 'OR')
frame.to_csv('PortlandSkills.csv', index = False)
# Out:
# There were 21 jobs found, Portland
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 10 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:132: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
#figure, frame = skills_info(city = 'Oklahoma City', state = 'OK')
#frame.to_csv('OklahomaCitySkills.csv', index = False)
# Out:
# There were 49 jobs found, Oklahoma City
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Done with collecting the job postings!
# There were 26 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Milwaukee', state = 'WI')
frame.to_csv('MilwaukeeSkills.csv', index = False)
# Out:
# There were 8 jobs found, Milwaukee
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-2b8be8a9629b> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Milwaukee', state = 'WI')
#       2 frame.to_csv('MilwaukeeSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Las Vegas', state = 'NV')
frame.to_csv('LasVegasSkills.csv', index = False)
# Out:
# There were 3 jobs found, Las Vegas
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-26bd6e040d93> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Las Vegas', state = 'NV')
#       2 frame.to_csv('LasVegasSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
#figure, frame = skills_info(city = 'Albuquerque', state = 'NM')
#frame.to_csv('AlbuquerqueSkills.csv', index = False)
# Out:
# There were 152 jobs found, Albuquerque
# Getting page 1
# Getting page

# %%
figure, frame = skills_info(city = 'Tucson', state = 'AZ')
frame.to_csv('TucsonSkills.csv', index = False)
# Out:
# There were 1 jobs found, Tucson
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-53f1bb45e01f> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Tucson', state = 'AZ')
#       2 frame.to_csv('TucsonSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Fresno', state = 'CA')
frame.to_csv('FresnoSkills.csv', index = False)
# Out:
# There were 18 jobs found, Fresno
# Getting page 1
# Done with collecting the job postings!
# There were 11 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Sacramento', state = 'CA')
frame.to_csv('SacramentoSkills.csv', index = False)
# Out:
# There were 2 jobs found, Sacramento
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-692405724998> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Sacramento', state = 'CA')
#       2 frame.to_csv('SacramentoSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Long Beach', state = 'CA')
frame.to_csv('LongBeachSkills.csv', index = False)
# Out:
# There were 97 jobs found, Long Beach
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Done with collecting the job postings!
# There were 51 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Kansas City', state = 'MO')
frame.to_csv('KansasSkills.csv', index = False)
# Out:
# There were 8 jobs found, Kansas City
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-ab99933d78d7> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Kansas City', state = 'MO')
#       2 frame.to_csv('KansasSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Mesa', state = 'AZ')
frame.to_csv('MesaSkills.csv', index = False)
# Out:
# There were 18 jobs found, Mesa
# Getting page 1
# Done with collecting the job postings!
# There were 6 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Virginia Beach', state = 'VA')
frame.to_csv('VirginiaBeachSkills.csv', index = False)
# Out:
# There were 25 jobs found, Virginia Beach
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 12 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Atlanta', state = 'GA')
frame.to_csv('AtlantaSkills.csv', index = False)
# Out:
# There were 55 jobs found, Atlanta
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Done with collecting the job postings!
# There were 37 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Colorado Springs', state = 'CO')
frame.to_csv('ColoradoSpringsSkills.csv', index = False)
# Out:
# There were 1 jobs found, Colorado Springs
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-aec8b1efa986> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Colorado Springs', state = 'CO')
#       2 frame.to_csv('ColoradoSpringsSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Raleigh', state = 'NC')
frame.to_csv('RaleighSkills.csv', index = False)
# Out:
# There were 16 jobs found, Raleigh
# Getting page 1
# Done with collecting the job postings!
# There were 4 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Omaha', state = 'NE')
frame.to_csv('OmahaSkills.csv', index = False)
# Out:
# There were 21 jobs found, Omaha
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 10 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Miami', state = 'FL')
frame.to_csv('MiamiSkills.csv', index = False)
# Out:
# There were 11 jobs found, Miami
# Getting page 1
# Done with collecting the job postings!
# There were 1 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Oakland', state = 'CA')
frame.to_csv('OaklandSkills.csv', index = False)
# Out:
# There were 372 jobs found, Oakland
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Getting page 13
# Getting page 14
# Getting page 15
# Getting page 16
# Getting page 17
# Getting page 18
# Getting page 19
# Getting page 20
# Getting page 21
# Getting page 22
# Getting page 23
# Getting page 24
# Getting page 25
# Getting page 26
# Getting page 27
# Getting page 28
# Getting page 29
# Getting page 30
# Getting page 31
# Getting page 32
# Getting page 33
# Getting page 34
# Getting page 35
# Getting page 36
# Getting page 37
# Done with collecting the job postings!
# There were 270 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Tulsa', state = 'OK')
frame.to_csv('TulsaSkills.csv', index = False)
# Out:
# There were 13 jobs found, Tulsa
# Getting page 1
# Done with collecting the job postings!
# There were 1 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-ae8428af8b6e> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Tulsa', state = 'OK')
#       2 frame.to_csv('TulsaSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     136
#     137     final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None,
# --> 138                               title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + city_title)
#     139
#     140     final_plot.set_ylabel('Percentage Appearing in Job Ads')
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3669                           fontsize=fontsize, colormap=colormap, table=table,
#    3670                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3671                           sort_columns=sort_columns, **kwds)
#    3672     __call__.__doc__ = plot_frame.__doc__
#    3673
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2554                  yerr=yerr, xerr=xerr,
#    2555                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2556                  **kwds)
#    2557
#    2558
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2382         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2383
# -> 2384     plot_obj.generate()
#    2385     plot_obj.draw()
#    2386     return plot_obj.result
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     983     def generate(self):
#     984         self._args_adjust()
# --> 985         self._compute_plot_data()
#     986         self._setup_subplots()
#     987         self._make_plot()
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _compute_plot_data(self)
#    1092         if is_empty:
#    1093             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1094                             'plot'.format(numeric_data.__class__.__name__))
#    1095
#    1096         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
figure, frame = skills_info(city = 'Minneapolis', state = 'MN')
frame.to_csv('MinneapolisSkills.csv', index = False)
# Out:
# There were 20 jobs found, Minneapolis
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 8 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Cleveland', state = 'OH')
frame.to_csv('ClevelandSkills.csv', index = False)
# Out:
# There were 8 jobs found, Cleveland
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-cb19ba799d0d> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Cleveland', state = 'OH')
#       2 frame.to_csv('ClevelandSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Wichita', state = 'KS')
frame.to_csv('WichitaSkills.csv', index = False)
# Out:
# There were 10 jobs found, Wichita
# Getting page 1
# Done with collecting the job postings!
# There were 14 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Arlington', state = 'TX')
frame.to_csv('ArlingtonSkills.csv', index = False)
# Out:
# There were 49 jobs found, Arlington
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Done with collecting the job postings!
# There were 19 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'New Orleans', state = 'LA')
frame.to_csv('NewOrleansSkills.csv', index = False)
# Out:
# There were 22 jobs found, New Orleans
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 20 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Bakersfield', state = 'CA')
frame.to_csv('BakersfieldSkills.csv', index = False)
# Out:
# There were 9 jobs found, Bakersfield
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-287234ee949a> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Bakersfield', state = 'CA')
#       2 frame.to_csv('BakersfieldSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Tampa', state = 'FL')
frame.to_csv('TampaSkills.csv', index = False)
# Out:
# There were 16 jobs found, Tampa
# Getting page 1
# Done with collecting the job postings!
# There were 3 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Honolulu', state = 'HI')
frame.to_csv('HonoluluSkills.csv', index = False)
# Out:
# There were 3 jobs found, Honolulu
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-5aee2e782e76> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Honolulu', state = 'HI')
#       2 frame.to_csv('HonoluluSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Anaheim', state = 'CA')
frame.to_csv('AnaheimSkills.csv', index = False)
# Out:
# There were 61 jobs found, Anaheim
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Done with collecting the job postings!
# There were 34 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Aurora', state = 'CO')
frame.to_csv('AuroraSkills.csv', index = False)
# Out:
# There were 45 jobs found, Aurora
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Done with collecting the job postings!
# There were 30 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Santa Ana', state = 'CA')
frame.to_csv('Santa AnaSkills.csv', index = False)
# Out:
# There were 27 jobs found, Santa Ana
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 13 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'St. Louis', state = 'MO')
frame.to_csv('St.LouisSkills.csv', index = False)
# Out:
# There were 50 jobs found, St. Louis
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Done with collecting the job postings!
# There were 23 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Riverside', state = 'CA')
frame.to_csv('RiversideSkills.csv', index = False)
# Out:
# There were 5 jobs found, Riverside
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-cf50112f2ffe> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Riverside', state = 'CA')
#       2 frame.to_csv('RiversideSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Corpus Christi', state = 'TX')
frame.to_csv('CorpusChristiSkills.csv', index = False)
# Out:
# There were 4 jobs found, Corpus Christi
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-53d3eb405bee> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Corpus Christi', state = 'TX')
#       2 frame.to_csv('CorpusChristiSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Pittsburgh', state = 'PA')
frame.to_csv('PittsburghSkills.csv', index = False)
# Out:
# There were 15 jobs found, Pittsburgh
# Getting page 1
# Done with collecting the job postings!
# There were 1 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Lexington', state = 'KY')
frame.to_csv('LexingtonSkills.csv', index = False)
# Out:
# There were 12 jobs found, Lexington
# Getting page 1
# Done with collecting the job postings!
# There were 1 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-877b799be2f9> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Lexington', state = 'KY')
#       2 frame.to_csv('LexingtonSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     136
#     137     final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None,
# --> 138                               title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + city_title)
#     139
#     140     final_plot.set_ylabel('Percentage Appearing in Job Ads')
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3669                           fontsize=fontsize, colormap=colormap, table=table,
#    3670                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3671                           sort_columns=sort_columns, **kwds)
#    3672     __call__.__doc__ = plot_frame.__doc__
#    3673
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2554                  yerr=yerr, xerr=xerr,
#    2555                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2556                  **kwds)
#    2557
#    2558
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2382         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2383
# -> 2384     plot_obj.generate()
#    2385     plot_obj.draw()
#    2386     return plot_obj.result
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     983     def generate(self):
#     984         self._args_adjust()
# --> 985         self._compute_plot_data()
#     986         self._setup_subplots()
#     987         self._make_plot()
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _compute_plot_data(self)
#    1092         if is_empty:
#    1093             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1094                             'plot'.format(numeric_data.__class__.__name__))
#    1095
#    1096         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
figure, frame = skills_info(city = 'Anchorage', state = 'AK')
frame.to_csv('AnchorageSkills.csv', index = False)
# Out:
# There were 9 jobs found, Anchorage
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-eff71fc59462> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Anchorage', state = 'AK')
#       2 frame.to_csv('AnchorageSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Stockton', state = 'CA')
frame.to_csv('StocktonSkills.csv', index = False)
# Out:
# There were 5 jobs found, Stockton
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-97d3a0b6b812> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Stockton', state = 'CA')
#       2 frame.to_csv('StocktonSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Cincinnati', state = 'OH')
frame.to_csv('CincinnatiSkills.csv', index = False)
# Out:
# There were 29 jobs found, Cincinnati
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 11 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'St. Paul', state = 'MN')
frame.to_csv('St.PaulSkills.csv', index = False)
# Out:
# There were 20 jobs found, St. Paul
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 8 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Toledo', state = 'OH')
frame.to_csv('ToledoSkills.csv', index = False)
# Out:
# There were 10 jobs found, Toledo
# Getting page 1
# Done with collecting the job postings!
# There were 12 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Newark', state = 'NJ')
frame.to_csv('NewarkSkills.csv', index = False)
# Out:
# There were 387 jobs found, Newark
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Getting page 13
# Getting page 14
# Getting page 15
# Getting page 16
# Getting page 17
# Getting page 18
# Getting page 19
# Getting page 20
# Getting page 21
# Getting page 22
# Getting page 23
# Getting page 24
# Getting page 25
# Getting page 26
# Getting page 27
# Getting page 28
# Getting page 29
# Getting page 30
# Getting page 31
# Getting page 32
# Getting page 33
# Getting page 34
# Getting page 35
# Getting page 36
# Getting page 37
# Getting page 38
# Done with collecting the job postings!
# There were 284 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Greensboro', state = 'NC')
frame.to_csv('GreensboroSkills.csv', index = False)
# Out:
# There were 2 jobs found, Greensboro
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-13d50a69ce65> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Greensboro', state = 'NC')
#       2 frame.to_csv('GreensboroSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Plano', state = 'TX')
frame.to_csv('PlanoSkills.csv', index = False)
# Out:
# There were 53 jobs found, Plano
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Done with collecting the job postings!
# There were 26 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Henderson', state = 'NV')
frame.to_csv('HendersonSkills.csv', index = False)
# Out:
# There were 3 jobs found, Henderson
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-ac8fd3cfdef4> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Henderson', state = 'NV')
#       2 frame.to_csv('HendersonSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Lincoln', state = 'NE')
frame.to_csv('LincolnSkills.csv', index = False)
# Out:
# There were 1 jobs found, Lincoln
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-5895ef1364ac> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Lincoln', state = 'NE')
#       2 frame.to_csv('LincolnSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Buffalo', state = 'NY')
frame.to_csv('BuffaloSkills.csv', index = False)
# Out:
# There were 1 jobs found, Buffalo
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-7ff183e72ebe> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Buffalo', state = 'NY')
#       2 frame.to_csv('BuffaloSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Fort Wayne', state = 'IN')
frame.to_csv('FortWayneSkills.csv', index = False)
# Out:
# There were 4 jobs found, Fort Wayne
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-1eb69fe04213> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Fort Wayne', state = 'IN')
#       2 frame.to_csv('FortWayneSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Jersey City', state = 'NJ')
frame.to_csv('JerseySkills.csv', index = False)
# Out:
# There were 378 jobs found, Jersey City
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Getting page 13
# Getting page 14
# Getting page 15
# Getting page 16
# Getting page 17
# Getting page 18
# Getting page 19
# Getting page 20
# Getting page 21
# Getting page 22
# Getting page 23
# Getting page 24
# Getting page 25
# Getting page 26
# Getting page 27
# Getting page 28
# Getting page 29
# Getting page 30
# Getting page 31
# Getting page 32
# Getting page 33
# Getting page 34
# Getting page 35
# Getting page 36
# Getting page 37
# Done with collecting the job postings!
# There were 240 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Chula Vista', state = 'CA')
frame.to_csv('ChulaVistaSkills.csv', index = False)
# Out:
# There were 38 jobs found, Chula Vista
# Getting page 1
# Getting page 2
# Getting page 3
# Done with collecting the job postings!
# There were 17 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Orlando', state = 'FL')
frame.to_csv('OrlandoSkills.csv', index = False)
# Out:
# There were 8 jobs found, Orlando
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-431fb8fd7b6f> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Orlando', state = 'FL')
#       2 frame.to_csv('OrlandoSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'St. Petersburg', state = 'FL')
frame.to_csv('St.PetersburgSkills.csv', index = False)
# Out:
# There were 16 jobs found, St. Petersburg
# Getting page 1
# Done with collecting the job postings!
# There were 3 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Norfolk', state = 'VA')
frame.to_csv('NorfolkSkills.csv', index = False)
# Out:
# There were 1 jobs found, Norfolk
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-93b445b0e936> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Norfolk', state = 'VA')
#       2 frame.to_csv('NorfolkSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Chandler', state = 'AZ')
frame.to_csv('ChandlerSkills.csv', index = False)
# Out:
# There were 16 jobs found, Chandler
# Getting page 1
# Done with collecting the job postings!
# There were 5 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
#figure, frame = skills_info(city = 'Laredo', state = 'TX')
#frame.to_csv('LaredoSkills.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-25ec6ca7bb5d> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Laredo', state = 'TX')
#       2 frame.to_csv('LaredoSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#      42     # Now find out how many jobs there were
#      43
# ---> 44     num_jobs_area = soup.find(id = 'searchCount').string.encode('utf-8') # Now extract the total number of jobs found
#      45                                                                          # The 'searchCount' object has this
#      46
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %%
figure, frame = skills_info(city = 'Madison', state = 'WI')
frame.to_csv('MadisonSkills.csv', index = False)
# Out:
# There were 15 jobs found, Madison
# Getting page 1
# Done with collecting the job postings!
# There were 1 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Durham', state = 'NC')
frame.to_csv('DurhamSkills.csv', index = False)
# Out:
# There were 17 jobs found, Durham
# Getting page 1
# Done with collecting the job postings!
# There were 4 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Lubbock', state = 'TX')
frame.to_csv('LubbockSkills.csv', index = False)
# Out:
# There were 4 jobs found, Lubbock
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-a20da4c4c6ac> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Lubbock', state = 'TX')
#       2 frame.to_csv('LubbockSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Winston-Salem', state = 'NC')
frame.to_csv('WinstonSalemSkills.csv', index = False)
# Out:
# There were 1 jobs found, Winston-Salem
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-f3d3a06cdb82> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Winston-Salem', state = 'NC')
#       2 frame.to_csv('WinstonSalemSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Garland', state = 'TX')
frame.to_csv('GarlandSkills.csv', index = False)
# Out:
# There were 53 jobs found, Garland
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Done with collecting the job postings!
# There were 27 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Glendale', state = 'AZ')
frame.to_csv('GlendaleSkills.csv', index = False)
# Out:
# There were 18 jobs found, Glendale
# Getting page 1
# Done with collecting the job postings!
# There were 6 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Hialeah', state = 'FL')
frame.to_csv('HialeahSkills.csv', index = False)
# Out:
# There were 12 jobs found, Hialeah
# Getting page 1
# Done with collecting the job postings!
# There were 1 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Reno', state = 'NV')
frame.to_csv('RenoSkills.csv', index = False)
# Out:
# There were 39 jobs found, Reno
# Getting page 1
# Getting page 2
# Getting page 3
# Done with collecting the job postings!
# There were 13 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Baton Rouge;', state = 'LA')
frame.to_csv('BatonRouge;Skills.csv', index = False)
# Out:
# There were 23 jobs found, Baton Rouge;
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 15 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-6acb217868b4> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Baton Rouge;', state = 'LA')
#       2 frame.to_csv('BatonRouge;Skills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     136
#     137     final_plot = final_frame.plot(x = 'Term', kind = 'bar', legend = None,
# --> 138                               title = 'Percentage of Data Scientist Job Ads with a Key Skill, ' + city_title)
#     139
#     140     final_plot.set_ylabel('Percentage Appearing in Job Ads')
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3669                           fontsize=fontsize, colormap=colormap, table=table,
#    3670                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3671                           sort_columns=sort_columns, **kwds)
#    3672     __call__.__doc__ = plot_frame.__doc__
#    3673
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2554                  yerr=yerr, xerr=xerr,
#    2555                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2556                  **kwds)
#    2557
#    2558
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2382         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2383
# -> 2384     plot_obj.generate()
#    2385     plot_obj.draw()
#    2386     return plot_obj.result
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     983     def generate(self):
#     984         self._args_adjust()
# --> 985         self._compute_plot_data()
#     986         self._setup_subplots()
#     987         self._make_plot()
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _compute_plot_data(self)
#    1092         if is_empty:
#    1093             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1094                             'plot'.format(numeric_data.__class__.__name__))
#    1095
#    1096         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
figure, frame = skills_info(city = 'Irvine', state = 'CA')
frame.to_csv('IrvineSkills.csv', index = False)
# Out:
# There were 27 jobs found, Irvine
# Getting page 1
# Getting page 2
# Done with collecting the job postings!
# There were 14 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Chesapeake', state = 'VA')
frame.to_csv('ChesapeakeSkills.csv', index = False)
# Out:
# There were 1 jobs found, Chesapeake
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-7781eced82c3> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Chesapeake', state = 'VA')
#       2 frame.to_csv('ChesapeakeSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Irving', state = 'TX')
frame.to_csv('IrvingSkills.csv', index = False)
# Out:
# There were 55 jobs found, Irving
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Done with collecting the job postings!
# There were 31 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Scottsdale', state = 'AZ')
frame.to_csv('ScottsdaleSkills.csv', index = False)
# Out:
# There were 18 jobs found, Scottsdale
# Getting page 1
# Done with collecting the job postings!
# There were 6 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'North Las Vegas', state = 'NV')
frame.to_csv('NorthLasVegasSkills.csv', index = False)
# Out:
# There were 3 jobs found, North Las Vegas
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-56d29406d90a> in <module>()
# ----> 1 figure, frame = skills_info(city = 'North Las Vegas', state = 'NV')
#       2 frame.to_csv('NorthLasVegasSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Fremont', state = 'CA')
frame.to_csv('FremontSkills.csv', index = False)
# Out:
# There were 335 jobs found, Fremont
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Getting page 5
# Getting page 6
# Getting page 7
# Getting page 8
# Getting page 9
# Getting page 10
# Getting page 11
# Getting page 12
# Getting page 13
# Getting page 14
# Getting page 15
# Getting page 16
# Getting page 17
# Getting page 18
# Getting page 19
# Getting page 20
# Getting page 21
# Getting page 22
# Getting page 23
# Getting page 24
# Getting page 25
# Getting page 26
# Getting page 27
# Getting page 28
# Getting page 29
# Getting page 30
# Getting page 31
# Getting page 32
# Getting page 33
# Done with collecting the job postings!
# There were 233 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'Gilbert', state = 'AZ')
frame.to_csv('GilbertSkills.csv', index = False)
# Out:
# There were 16 jobs found, Gilbert
# Getting page 1
# Done with collecting the job postings!
# There were 5 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
figure, frame = skills_info(city = 'San Bernardino', state = 'CA')
frame.to_csv('SanBernardinoSkills.csv', index = False)
# Out:
# There were 1 jobs found, San Bernardino
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-1aa79ed35108> in <module>()
# ----> 1 figure, frame = skills_info(city = 'San Bernardino', state = 'CA')
#       2 frame.to_csv('SanBernardinoSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Boise', state = 'ID')
frame.to_csv('BoiseSkills.csv', index = False)
# Out:
# There were 6 jobs found, Boise
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-26b6199c6781> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Boise', state = 'ID')
#       2 frame.to_csv('BoiseSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Birmingham', state = 'AL')
frame.to_csv('BirminghamSkills.csv', index = False)
# Out:
# There were 2 jobs found, Birmingham
# Done with collecting the job postings!
# There were 0 jobs successfully found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-d0f3072f4ea8> in <module>()
# ----> 1 figure, frame = skills_info(city = 'Birmingham', state = 'AL')
#       2 frame.to_csv('BirminghamSkills.csv', index = False)
#
# <ipython-input-41-8665c0c79261> in skills_info(city, state)
#     126     # Change the values to reflect a percentage of the postings
#     127
# --> 128     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings
#     129                                                                                   #  having that term
#     130
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     567             result, changed = com._maybe_upcast_putmask(result, ~mask, np.nan)
#     568
# --> 569         result = com._fill_zeros(result, x, y, name, fill_zeros)
#     570         return result
#     571
#
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _fill_zeros(result, x, y, name, fill)
#    1402             # GH 7325, mask and nans must be broadcastable (also: PR 9308)
#    1403             # Raveling and then reshaping makes np.putmask faster
# -> 1404             mask = ((y == 0) & ~np.isnan(result)).ravel()
#    1405
#    1406             shape = result.shape
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
figure, frame = skills_info(city = 'Boulder', state = 'CO')
frame.to_csv('BoulderSkills.csv', index = False)
# Out:
# There were 43 jobs found, Boulder
# Getting page 1
# Getting page 2
# Getting page 3
# Getting page 4
# Done with collecting the job postings!
# There were 30 jobs successfully found.
# /Users/Yathor/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:133: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
